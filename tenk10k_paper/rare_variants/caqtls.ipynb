# %%
library(data.table)

# %%
caqtl_dir = '/directflow/SCCGGroupShare/projects/angxue/proj/tenk10k/caQTL/ms_tables/'
summary_file = paste0(caqtl_dir,'TenK10K.caQTL.1Mb.final_summary_qval005.csv')

# %%
df = as.data.frame(fread(summary_file))
head(df)
# Out:
#   phenotype_id             num_var beta_shape1 beta_shape2 true_df
# 1 chr1:8647508-8648197     6236    0.8629746   156.70200   248.5109
# 2 chr1:31903399-31906277   4245    0.7340282    68.03604   225.0327
# 3 chr1:33433641-33434193   4866    0.6328613    63.69748   212.7936
# 4 chr1:66330234-66331130   6441    0.7805625    90.82179   239.1331
# 5 chr1:66367191-66367978   6491    0.8143693   103.46184   252.4843
# 6 chr1:100359974-100360581 4712    0.7781683    58.49822   194.3361
#   pval_true_df
# 1 7.910841e-10
# 2 2.700125e-11
# 3 4.454003e-17
# 4 1.257853e-13
# 5 1.458413e-09
# 6 1.767710e-09
#   variant_id
# 1 1:8157894:GAAGAAGGAGAAGAAGAAGGAAGAGGAAGAGGAGGAGGAAGAAGAAAGAAGGAGGAGGAGGAGAAGGAGA:G
# 2 1:32708533:AT:A
# 3 1:32708533:AT:A
# 4 1:66075928:A:AC
# 5 1:66075928:A:AC
# 6 1:101258579:G:GTCTTTCTT
#   start_distance end_distance ma_samples ma_count af         pval_nominal
# 1 -489959        -489959      5           5       0.05813954 5.083390e-17
# ...

# %%
table(df$cell_types)
hist(df$af)
# Out:
#              ASDC    B_intermediate          B_memory           B_naive
#               122             11248              7389             11681
#         CD14_Mono         CD16_Mono           CD4_CTL         CD4_Naive
#             54564             23604              5860             19915
# CD4_Proliferating           CD4_TCM           CD4_TEM         CD8_Naive
#                30             26455              2488              6125
#           CD8_TCM           CD8_TEM              cDC1              cDC2
#               607             19657               156             10380
#               dnT               gdT              HSPC              MAIT
#              2733              3421               330              2903
#                NK     NK_CD56bright  NK_Proliferating               pDC
#             27959              3015               376              3949
#       Plasmablast              Treg
#               957              4241
# ...
